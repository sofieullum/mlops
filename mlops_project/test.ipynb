# %%
import torch
from src.mlops_project.data import corrupt_mnist
from src.mlops_project.model import Model
from src.mlops_project.train import train
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [14], line 4
#       2 from src.mlops_project.data import corrupt_mnist
#       3 from src.mlops_project.model import Model
# ----> 4 from src.mlops_project.train import train
#
# File c:\Users\sofie\OneDrive - Danmarks Tekniske Universitet\Kandidat\1. semester\02476 - Machine learning operations\mlops\mlops_project\src\mlops_project\train.py:6
#       3 import torch
#       4 import typer
# ----> 6 from mlops_project.data import corrupt_mnist
#       7 from mlops_project.model import Model
#       8 from omegaconf import DictConfig
#
# ModuleNotFoundError: No module named 'mlops_project'

# %%
train, test = corrupt_mnist()

train
# Out:
# c:\Users\sofie\OneDrive - Danmarks Tekniske Universitet\Kandidat\1. semester\02476 - Machine learning operations\mlops\mlops_project\src\mlops_project\data.py:45: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues re
# ...

# %%
assert len(train) == 30000
assert len(test) == 5000

# %%
for dataset in [train,test]:
    for x, y in dataset:
        assert x.shape == torch.Size([1,28,28])
        assert y in range (10)

# %%
train_targets = torch.unique(train.tensors[1])
assert (train_targets == torch.arange(0,10)).all()
test_targets = torch.unique(test.tensors[1])
assert (test_targets == torch.arange(0,10)).all()

# %%
x.shape
# Out:
# torch.Size([1, 28, 28])

# %%
model = Model()
x = torch.rand(1,1,28,28)
y = model(x, conv1_chnls=32, conv2_chnls=64, conv3_chnls=128, dr=0.5, num_classes=10)
y.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [8], line 3
#       1 model = Model()
#       2 x = torch.rand(1,1,28,28)
# ----> 3 y = model(x, conv1_chnls=32, conv2_chnls=64, conv3_chnls=128, dr=0.5, num_classes=10)
#       4 y.shape
#
# File c:\Users\sofie\anaconda3\envs\DeepLearning\Lib\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File c:\Users\sofie\anaconda3\envs\DeepLearning\Lib\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
# ...

# %%
from omegaconf import OmegaConf
from src.mlops_project.train import train

config_dict = {"learning_rate": 0.001,
               "batch_size": 32,
               "epochs": 2,  # Changed to 2
               "seed": 42,
               "conv1_channels": 32,
               "conv2_channels": 64,
               "conv3_channels": 128,
               "dropout_rate": 0.5,
               "num_classes": 10}

with initialize(version_base=None, config_path="../configs"):
    cfg = OmegaConf.create(config_dict)
    train.fn(cfg)  # Use .fn to bypass decorator
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [13], line 2
#       1 from omegaconf import OmegaConf
# ----> 2 from src.mlops_project.train import train
#       4 config_dict = {"learning_rate": 0.001,
#       5                "batch_size": 32,
#       6                "epochs": 2,  # Changed to 2
#    (...)
#      11                "dropout_rate": 0.5,
#      12                "num_classes": 10}
#      14 with initialize(version_base=None, config_path="../configs"):
#
# File c:\Users\sofie\OneDrive - Danmarks Tekniske Universitet\Kandidat\1. semester\02476 - Machine learning operations\mlops\mlops_project\src\mlops_project\train.py:6
#       3 import torch
#       4 import typer
# ----> 6 from mlops_project.data import corrupt_mnist
#       7 from mlops_project.model import Model
#       8 from omegaconf import DictConfig
#
# ...
